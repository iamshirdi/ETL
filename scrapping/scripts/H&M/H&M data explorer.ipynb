# %%
import pandas as pd
df2=pd.read_csv("H&M_new_born.csv", encoding='utf-8',index_col=False)
print(df2.count())
df2.head()
# Out:
# name           3611
# brand          3611
# gender         3611
# category       3611
# size           3611
# price          3611
# composition    3611
# color          3611
# url            3611
# img_url        3611
# article_no     3611
# blob_url       3611
# dtype: int64
#                 name brand  gender  category   size       price  composition  \
# 0  3-pack omlottbody   H&M  unisex  babybody  50-74  149,00 kr.  Bomull 100%
# 1  3-pack omlottbody   H&M  unisex  babybody  50-74   79,90 kr.  Bomull 100%
# 2  3-pack omlottbody   H&M  unisex  babybody  50-74   69,90 kr.  Bomull 100%
# 3  3-pack omlottbody   H&M  unisex  babybody  50-74  149,00 kr.  Bomull 100%
# 4  3-pack omlottbody   H&M  unisex  babybody  50-74   79,90 kr.  Bomull 100%
#
#                  color                                                url  \
# 0                  Vit  https://www2.hm.com/sv_se/productpage.07017840...
# 1    Mörkbeige/Prickig  https://www2.hm.com/sv_se/productpage.07017840...
# ...

# %%
import pandas as pd
df3=pd.read_csv("H&M_baby_boy.csv", encoding='utf-8',index_col=False)
print(df3.count())
df3.head()
# Out:
# name           4190
# brand          4190
# gender         4190
# category       4190
# size           4190
# price          4190
# composition    4190
# color          4190
# url            4190
# img_url        4190
# article_no     4190
# blob_url       4190
# dtype: int64
#           name brand gender  category    size       price  composition  \
# 0  5-pack body   H&M    boy  babybody  68-104  149,00 kr.  Bomull 100%
# 1  5-pack body   H&M    boy  babybody  68-104  149,00 kr.  Bomull 100%
# 2  5-pack body   H&M    boy  babybody  68-104  179,00 kr.  Bomull 100%
# 3  5-pack body   H&M    boy  babybody  68-104   59,90 kr.  Bomull 100%
# 4  5-pack body   H&M    boy  babybody  68-104   99,00 kr.  Bomull 100%
#
#               color                                                url  \
# 0  Ljusrosa/Ljusgrå  https://www2.hm.com/sv_se/productpage.05332610...
# 1   Ljusblå/Mörkgrå  https://www2.hm.com/sv_se/productpage.05332610...
# ...

# %%
import pandas as pd
df4=pd.read_csv("H&M_baby_girl.csv", encoding='utf-8',index_col=False)
print(df4.count())
df4.head()
# Out:
# name           4444
# brand          4444
# gender         4444
# category       4444
# size           4444
# price          4444
# composition    4444
# color          4444
# url            4444
# img_url        4444
# article_no     4444
# blob_url       4444
# dtype: int64
#           name brand gender  category    size       price  composition  \
# 0  5-pack body   H&M   girl  babybody  68-104  149,00 kr.  Bomull 100%
# 1  5-pack body   H&M   girl  babybody  68-104  149,00 kr.  Bomull 100%
# 2  5-pack body   H&M   girl  babybody  68-104  179,00 kr.  Bomull 100%
# 3  5-pack body   H&M   girl  babybody  68-104   59,90 kr.  Bomull 100%
# 4  5-pack body   H&M   girl  babybody  68-104   99,00 kr.  Bomull 100%
#
#               color                                                url  \
# 0  Ljusrosa/Ljusgrå  https://www2.hm.com/sv_se/productpage.05332610...
# 1   Ljusblå/Mörkgrå  https://www2.hm.com/sv_se/productpage.05332610...
# ...

# %%
import pandas as pd
df5=pd.read_csv("H&M_boy.csv", encoding='utf-8',index_col=False)
print(df5.count())
df5.head()
# Out:
# name           6507
# brand          6507
# gender         6507
# category       6507
# size           6507
# price          6507
# composition    6507
# color          6507
# url            6507
# img_url        6507
# article_no     6507
# blob_url       6507
# dtype: int64
#                name brand gender  category    size       price  \
# 0  2-pack badshorts   H&M    boy  badbyxor  92-140   99,00 kr.
# 1  2-pack badshorts   H&M    boy  badbyxor  92-140   79,90 kr.
# 2  2-pack badshorts   H&M    boy  badbyxor  92-140  149,00 kr.
# 3           Badbyxa   H&M    boy  badbyxor  92-140   39,90 kr.
# 4           Badbyxa   H&M    boy  badbyxor  92-140   39,90 kr.
#
#                   composition              color  \
# 0       Foder: Polyester 100%   Mörkblå/Mönstrad
# 1       Foder: Polyester 100%    Klarröd/Mörkblå
# 2       Foder: Polyester 100%  Neonorange/Randig
# 3        Foder: Polyamid 100%       Mörkblå/Grön
# 4  Polyester 85%, Elastan 15%        Röd/Mörkblå
#
# ...

# %%
import pandas as pd
df6=pd.read_csv("H&M_girl.csv", encoding='utf-8',index_col=False)
print(df6.count())
df6.head()
# Out:
# name           7689
# brand          7689
# gender         7689
# category       7689
# size           7689
# price          7689
# composition    7689
# color          7689
# url            7689
# img_url        7689
# article_no     7689
# blob_url       7689
# dtype: int64
#                        name brand gender    category    size       price  \
# 0        Baddräkt med tryck   H&M   girl    baddräkt  92-140  129,00 kr.
# 1  Skimrande volangbaddräkt   H&M   girl    baddräkt  92-140  149,00 kr.
# 2   Glittrig volangbaddräkt   H&M   girl    baddräkt  92-140  149,00 kr.
# 3                Benvärmare   H&M   girl  benvärmare  92-140   79,90 kr.
# 4                Benvärmare   H&M   girl  benvärmare  92-140   79,90 kr.
#
#                              composition              color  \
# 0                  Foder: Polyester 100%  Mörkblå/Enhörning
# 1                  Foder: Polyester 100%               Rosa
# 2     Volang: Polyester 83%, Elastan 17%     Ljusrosa/Frost
# ...

# %%
import pandas as pd
df7=pd.read_csv("H&M_boys.csv", encoding='utf-8',index_col=False)
print(df7.count())
df7.head()
# Out:
# name           4177
# brand          4177
# gender         4177
# category       4177
# size           4177
# price          4177
# composition    4177
# color          4177
# url            4177
# img_url        4177
# article_no     4177
# blob_url       4177
# dtype: int64
#                   name brand gender  category     size       price  \
# 0  Badshorts med tryck   H&M    boy  badbyxor  134-170  149,00 kr.
# 1  Badshorts med tryck   H&M    boy  badbyxor  134-170  149,00 kr.
# 2  Badshorts med tryck   H&M    boy  badbyxor  134-170   49,90 kr.
# 3  Badshorts med tryck   H&M    boy  badbyxor  134-170   69,90 kr.
# 4  Badshorts med tryck   H&M    boy  badbyxor  134-170   79,90 kr.
#
#              composition              color  \
# 0         Polyester 100%         Grå/Venice
# 1         Polyester 100%         Blå/Palmer
# 2         Polyester 100%  Svart/Gråmönstrad
# 3         Polyester 100%          Blå/Hajar
# 4  Foder: Polyester 100%     Svart/Stjärnor
#
# ...

# %%
import pandas as pd
df8=pd.read_csv("H&M_girls.csv", encoding='utf-8',index_col=False)
print(df8.count())
df8.head()
# Out:
# name           5477
# brand          5477
# gender         5477
# category       5477
# size           5477
# price          5477
# composition    5477
# color          5477
# url            5477
# img_url        5477
# article_no     5477
# blob_url       5477
# dtype: int64
#                  name brand gender    category     size       price  \
# 0      2-pack armband   H&M   girl     armband  134-170   39,90 kr.
# 1     2-pack baddräkt   H&M   girl    baddräkt  134-170  179,00 kr.
# 2  Baddräkt med tryck   H&M   girl    baddräkt  134-170  149,00 kr.
# 3  Baddräkt med tryck   H&M   girl    baddräkt  134-170   69,90 kr.
# 4          Benvärmare   H&M   girl  benvärmare  134-170   79,90 kr.
#
#                              composition              color  \
# 0                Polyester 60%, Järn 40%      Rosa/Mönstrad
# 1                  Foder: Polyester 100%   Mörkblå/Stjärnor
# 2                  Foder: Polyester 100%  Rosa/Hello summer
# ...

# %%
frames = [df2, df3, df4, df5, df6,df7,df8]
result = pd.concat(frames)
result.head()
# Out:
#                 name brand  gender  category   size       price  composition  \
# 0  3-pack omlottbody   H&M  unisex  babybody  50-74  149,00 kr.  Bomull 100%
# 1  3-pack omlottbody   H&M  unisex  babybody  50-74   79,90 kr.  Bomull 100%
# 2  3-pack omlottbody   H&M  unisex  babybody  50-74   69,90 kr.  Bomull 100%
# 3  3-pack omlottbody   H&M  unisex  babybody  50-74  149,00 kr.  Bomull 100%
# 4  3-pack omlottbody   H&M  unisex  babybody  50-74   79,90 kr.  Bomull 100%
#
#                  color                                                url  \
# 0                  Vit  https://www2.hm.com/sv_se/productpage.07017840...
# 1    Mörkbeige/Prickig  https://www2.hm.com/sv_se/productpage.07017840...
# 2             Gul/Djur  https://www2.hm.com/sv_se/productpage.07017840...
# 3      Mörkblå/Ankaren  https://www2.hm.com/sv_se/productpage.07017840...
# 4  Ljusrosa/Jordgubbar  https://www2.hm.com/sv_se/productpage.07017840...
#
# ...

# %%
result.count()
# Out:
# name           36095
# brand          36095
# gender         36095
# category       36095
# size           36095
# price          36095
# composition    36095
# color          36095
# url            36095
# img_url        36095
# article_no     36095
# blob_url       36095
# dtype: int64

# %%
len(result['article_no'].unique())
# Out:
# 9890

# %%
13101-1456*2
# Out:
# 10189

# %%
result.drop_duplicates().count()
# Out:
# name           13101
# brand          13101
# gender         13101
# category       13101
# size           13101
# price          13101
# composition    13101
# color          13101
# url            13101
# img_url        13101
# article_no     13101
# blob_url       13101
# dtype: int64

# %%
result[result['gender']=='unisex'].drop_duplicates().count()
# Out:
# name           1456
# brand          1456
# gender         1456
# category       1456
# size           1456
# price          1456
# composition    1456
# color          1456
# url            1456
# img_url        1456
# article_no     1456
# blob_url       1456
# dtype: int64

# %%
len(result['name'].unique())
# Out:
# 1271

# %%
len(result['price'].unique())
# Out:
# 40

# %%
df = result.drop_duplicates()
df.count()
# Out:
# name           13101
# brand          13101
# gender         13101
# category       13101
# size           13101
# price          13101
# composition    13101
# color          13101
# url            13101
# img_url        13101
# article_no     13101
# blob_url       13101
# dtype: int64

# %%
df.groupby('article_no').count()
# Out:
#             name  brand  gender  category  size  price  composition  color  \
# article_no
# 146706001      3      3       3         3     3      3            3      3
# 146706004      3      3       3         3     3      3            3      3
# 174057017      3      3       3         3     3      3            3      3
# 174057019      3      3       3         3     3      3            3      3
# 174057020      3      3       3         3     3      3            3      3
# 174057022      3      3       3         3     3      3            3      3
# 174057024      3      3       3         3     3      3            3      3
# 174057025      3      3       3         3     3      3            3      3
# 174057026      3      3       3         3     3      3            3      3
# 174057027      3      3       3         3     3      3            3      3
# 174057028      3      3       3         3     3      3            3      3
# ...

# %%
df[df['article_no']==811596002]
# Out:
#                  name brand  gender  category    size       price  \
# 1693  2-pack leggings   H&M  unisex  leggings   50-74  129,00 kr.
# 1881  2-pack leggings   H&M    girl  leggings  68-104  129,00 kr.
#
#                  composition                 color  \
# 1693  Bomull 95%, Elastan 5%  Mörk dimrosa/Blommig
# 1881  Bomull 95%, Elastan 5%  Mörk dimrosa/Blommig
#
#                                                     url  \
# 1693  https://www2.hm.com/sv_se/productpage.08115960...
# 1881  https://www2.hm.com/sv_se/productpage.08115960...
#
#                                                 img_url  article_no  \
# 1693  https://lp2.hm.com/hmgoepprod?set=source[/9d/1...   811596002
# 1881  https://lp2.hm.com/hmgoepprod?set=source[/9d/1...   811596002
#
#                                                blob_url
# 1693  https://storage.googleapis.com/urbankiddo/H%26...
# 1881  https://storage.googleapis.com/urbankiddo/H%26...

# %% [markdown]
# ## same article number because of unisex both male and female also note sizes

# %%
df[df['article_no']==146706001]
# Out:
#            name brand  gender  category    size      price  composition color  \
# 86  3-pack body   H&M  unisex  babybody   50-74  89,90 kr.  Bomull 100%   Vit
# 26  3-pack body   H&M     boy  babybody  68-104  89,90 kr.  Bomull 100%   Vit
# 39  3-pack body   H&M    girl  babybody  68-104  89,90 kr.  Bomull 100%   Vit
#
#                                                   url  \
# 86  https://www2.hm.com/sv_se/productpage.01467060...
# 26  https://www2.hm.com/sv_se/productpage.01467060...
# 39  https://www2.hm.com/sv_se/productpage.01467060...
#
#                                               img_url  article_no  \
# 86  https://lp2.hm.com/hmgoepprod?set=source[/9d/4...   146706001
# 26  https://lp2.hm.com/hmgoepprod?set=source[/9d/4...   146706001
# 39  https://lp2.hm.com/hmgoepprod?set=source[/9d/4...   146706001
#
#                                              blob_url
# 86  https://storage.googleapis.com/urbankiddo/H%26...
# 26  https://storage.googleapis.com/urbankiddo/H%26...
# ...

# %%
pd.set_option('display.max_colwidth', -1) #full colunm dispaly
df[df['article_no']==146706001]['url']
# Out:
# 86    https://www2.hm.com/sv_se/productpage.0146706001.html
# 26    https://www2.hm.com/sv_se/productpage.0146706001.html
# 39    https://www2.hm.com/sv_se/productpage.0146706001.html
# Name: url, dtype: object

# %%
df2=df[df['article_no']==146706001]
df2.head()
# Out:
#            name brand  gender  category    size      price  composition color  \
# 86  3-pack body  H&M   unisex  babybody  50-74   89,90 kr.  Bomull 100%  Vit
# 26  3-pack body  H&M   boy     babybody  68-104  89,90 kr.  Bomull 100%  Vit
# 39  3-pack body  H&M   girl    babybody  68-104  89,90 kr.  Bomull 100%  Vit
#
#                                                       url  \
# 86  https://www2.hm.com/sv_se/productpage.0146706001.html
# 26  https://www2.hm.com/sv_se/productpage.0146706001.html
# 39  https://www2.hm.com/sv_se/productpage.0146706001.html
#
#                                                                                                                                                                                                       img_url  \
# 86  https://lp2.hm.com/hmgoepprod?set=source[/9d/47/9d477700382320194173b3e400db650e7cc3dcdd.jpg],origin[dam],category[kids_babyboy_bodies],type[DESCRIPTIVESTILLLIFE],hmver[1]&call=url[file:/product/main]+
# ...

# %%
df2 = df2.drop_duplicates(['article_no'])
df2.head()
# Out:
#            name brand  gender  category   size      price  composition color  \
# 86  3-pack body  H&M   unisex  babybody  50-74  89,90 kr.  Bomull 100%  Vit
#
#                                                       url  \
# 86  https://www2.hm.com/sv_se/productpage.0146706001.html
#
#                                                                                                                                                                                                       img_url  \
# 86  https://lp2.hm.com/hmgoepprod?set=source[/9d/47/9d477700382320194173b3e400db650e7cc3dcdd.jpg],origin[dam],category[kids_babyboy_bodies],type[DESCRIPTIVESTILLLIFE],hmver[1]&call=url[file:/product/main]+
#
#     article_no                                                    blob_url
# 86  146706001   https://storage.googleapis.com/urbankiddo/H%26M/0146706001

# %%
df.count()
# Out:
# name           13101
# brand          13101
# gender         13101
# category       13101
# size           13101
# price          13101
# composition    13101
# color          13101
# url            13101
# img_url        13101
# article_no     13101
# blob_url       13101
# dtype: int64

# %%
df.to_csv('H&M.csv',index=False) #for rows not showing
