# %%
import pandas as pd
dfa=pd.read_csv("raw_data.csv")
dfb=pd.read_csv("cleaned_data.csv")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=dfb
df['gender']=df['gender'].str.replace('MALE','boy')
df['gender']=df['gender'].str.replace('Pojke','boy')
df['gender']=df['gender'].str.replace('Flicka','girl')
df['gender']=df['gender'].str.replace('Barn - Unisex','unisex')
df['gender']=df['gender'].str.replace('FEboy','boy')
df['gender']=df['gender'].str.replace('Barn','unisex')
df=df[df['gender']!='Junior']

df['gender'].unique()
# Out:
# array(['unisex', 'boy', 'girl'], dtype=object)

# %%
df12=df
df12['price'].unique().size
# Out:
# 1566

# %%
df12[df12['article_no']=='lekmer/197134']['price']
# Out:
# 464639    199
# 466008    199
# Name: price, dtype: object

# %%
import numpy as np
# df12['price']=df12['price'].str.replace("'","")
df12=df12[df12['price']!='(Kommer']
# df2['price']=df2['price'].dropna()
# df2=df2[df2['price']!=pd.np.nan]
# df2=df2[df2['price']!='']
# df2['price']=df2['price'].fillna(-1)
df12['price']=df12['price'].astype(float)
df12['price']=df12['price'].round()
df12['price']=df12['price'].astype(int)


set(df12['price'].unique().tolist())
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df3=df12
df3['category'].unique().size
# Out:
# 423

# %%
df3['brand'].unique().size
# Out:
# 688

# %%
df3['category'].unique().size
# Out:
# 423

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1) #full colunm dispaly
df3[df3['category']=='PIKE/RUGBYTRöJOR']
# dfa[dfa['article_no']=='kidsbrandstore/product-entry-id-25339']
# Out:
#                                    article_no gender          category  price  \
# 418007  kidsbrandstore/product-entry-id-25339  boy    PIKE/RUGBYTRöJOR  439
# 418008  kidsbrandstore/product-entry-id-25339  boy    PIKE/RUGBYTRöJOR  439
# 418009  kidsbrandstore/product-entry-id-25339  boy    PIKE/RUGBYTRöJOR  439
# 418010  kidsbrandstore/product-entry-id-25339  boy    PIKE/RUGBYTRöJOR  439
# 418011  kidsbrandstore/product-entry-id-25339  boy    PIKE/RUGBYTRöJOR  439
# ...                                       ...  ...                 ...  ...
# 422950  kidsbrandstore/product-entry-id-25008  girl   PIKE/RUGBYTRöJOR  60
# 422951  kidsbrandstore/product-entry-id-25008  girl   PIKE/RUGBYTRöJOR  60
# 422952  kidsbrandstore/product-entry-id-25008  girl   PIKE/RUGBYTRöJOR  60
# 422953  kidsbrandstore/product-entry-id-25008  girl   PIKE/RUGBYTRöJOR  60
# 422954  kidsbrandstore/product-entry-id-25008  girl   PIKE/RUGBYTRöJOR  60
#
#            size       brand
# 418007  8Y       Lacoste
# ...

# %%
df3.to_csv('cleaning1.csv',index=False) #for rows not showing

# %%
# df3['category']=df3['category'].str.replace('babyscarf','Accessories/Scarf')
# df3['category']=df3['category'].str.replace('babybody','Bodysuits')
# df3['category']=df3['category'].str.replace('blus','Blouses')
# df3['category']=df3['category'].str.replace('byxor','Bottoms')
# df3['category']=df3['category'].str.replace('cardigan','Knitwear/Cardigan')
# df3['category']=df3['category'].str.replace('halsduk','Accessories/Scarf')
# df3['category']=df3['category'].str.replace('hatt','Accessories/Hats')
# df3['category']=df3['category'].str.replace('hårband','Accessories/Hairband')
# df3['category']=df3['category'].str.replace('jacka','Jackets')
# df3['category']=df3['category'].str.replace('jumpsuit','Jumpsuits')
# df3['category']=df3['category'].str.replace('kjol','Skirts')
# df3['category']=df3['category'].str.replace('klänning','Dresses')
# df3['category']=df3['category'].str.replace('leggings','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('mössa','Accessories/Mössor')
# df3['category']=df3['category'].str.replace('overall','Overalls')
# df3['category']=df3['category'].str.replace('pannband','Accessories/hairband')                                           
# df3['category']=df3['category'].str.replace('pufftrosa','Bottoms')
# df3['category']=df3['category'].str.replace('pyjamas','Pajamas')
# df3['category']=df3['category'].str.replace('skjorta','Tops')
# df3['category']=df3['category'].str.replace('skor','Footwear')
# df3['category']=df3['category'].str.replace('sovpåse','Accessories/Sleeping bags')
# df3['category']=df3['category'].str.replace('stickad tröja','Shirts')
# df3['category']=df3['category'].str.replace('strumpbyxor','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('skjorta','Dresses')                                          
# df3['category']=df3['category'].str.replace('shorts','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('strumpor','Footwear/Socks')
# df3['category']=df3['category'].str.replace('t-shirt','Shirts')
# df3['category']=df3['category'].str.replace('tofflor','Footwear/Slippers')
# df3['category']=df3['category'].str.replace('topp','Tops')                 
# df3['category']=df3['category'].str.replace('tröja','Winter Jackets/Sweaters')
# df3['category']=df3['category'].str.replace('vantar','Accessories/Gloves')
# df3['category']=df3['category'].str.replace('väst','Coats/Vest')
# df3['category']=df3['category'].str.replace('badbyxor','Bottoms/Swimming Trunks')
# df3['category']=df3['category'].str.replace('baddräkt','Badklader/Swimwear') #odd
# df3['category']=df3['category'].str.replace('dräkt','Costume Wear')
# df3['category']=df3['category'].str.replace('fluga','Accessories/Bowtie')
# df3['category']=df3['category'].str.replace('hängslen','Accessories/Braces')
# df3['category']=df3['category'].str.replace('jeans','Bottoms/Jeans')
# df3['category']=df3['category'].str.replace('keps','Accessories/Caps')                    
# df3['category']=df3['category'].str.replace('väska','Accessories/Bags')
# df3['category']=df3['category'].str.replace('badtröja','Badklader/Bathing Suit')
# df3['category']=df3['category'].str.replace('bikinitrosa','Bottoms/Bikinitrosa')
# df3['category']=df3['category'].str.replace('kappa','Coats')
# df3['category']=df3['category'].str.replace('mockasiner','Shoes/Mockasiner')
# df3['category']=df3['category'].str.replace('morgonrock','Badklader/Robe')
# df3['category']=df3['category'].str.replace('trosa','Bottoms/trosa')
# df3['category']=df3['category'].str.replace('tunika','Dresses/Tunics')
# df3['category']=df3['category'].str.replace('diadem','Accessories/Tiara')
# df3['category']=df3['category'].str.replace('handskar','Accessories/Gloves')
# df3['category']=df3['category'].str.replace('kalsonger','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('kostymväst','Coats/Vest')
# df3['category']=df3['category'].str.replace('leksak','Toys') #not needed 
# df3['category']=df3['category'].str.replace('långkalsonger','Bottoms/Long Underwear')
# df3['category']=df3['category'].str.replace('maskeradaccessoar','Costume Wear/Accessories')
# df3['category']=df3['category'].str.replace('skärp','Accessories/Belts')
# df3['category']=df3['category'].str.replace('solglasögon','Accessories/Sunglasses')
# df3['category']=df3['category'].str.replace('benvärmare','Bottoms/Legwarmers')
# df3['category']=df3['category'].str.replace('bikinitopp','Tops/Bikini')
# df3['category']=df3['category'].str.replace('bolero','Tops/Bolero')
# df3['category']=df3['category'].str.replace('halsband','Accessories/Necklace')
# df3['category']=df3['category'].str.replace('hårdekoration','Accessories/HairDecoration')
# df3['category']=df3['category'].str.replace('hårsnodd','Accessories/Hairtie')
# df3['category']=df3['category'].str.replace('hårspänne','Accessories/Hairpin')
# df3['category']=df3['category'].str.replace('läppbalsam','Accessories/Lipbalm')
# df3['category']=df3['category'].str.replace('nagellack','Accessories/Nailpolish')
# df3['category']=df3['category'].str.replace('nattlinne','Pajamas/Nightgown') 
# df3['category']=df3['category'].str.replace('pennfodral','Accessories/Pencilcase') #not needed
# df3['category']=df3['category'].str.replace('poncho','Tops/Poncho')
# df3['category']=df3['category'].str.replace('scarf','Accessories/Scarf')
# df3['category']=df3['category'].str.replace('armband','Accessories/Armband')
# df3['category']=df3['category'].str.replace('hörlurar','Accessories/Headphones')
# df3['category']=df3['category'].str.replace('simglasögon','Accessories/Sunglasses')
# df3['category']=df3['category'].str.replace('accessoarer','Accessories')
# df3['category']=df3['category'].str.replace('barnklanningar-tunikor','Dresses/Tunics')
# df3['category']=df3['category'].str.replace('bodys-bodysuits','Bodysuits')
# df3['category']=df3['category'].str.replace('fleeceklader','Tops/Fleece')       #includes all tops jackets bottoms                                    
# df3['category']=df3['category'].str.replace('hogtidsklader','Costume Wear/Holiday Clothing')
# df3['category']=df3['category'].str.replace('jumpsuits-byxdressar','Jumpsuits')
# df3['category']=df3['category'].str.replace('klad-gavoset','Klader/Giftset')                                           
# df3['category']=df3['category'].str.replace('nederdelar','Skirts')
# df3['category']=df3['category'].str.replace('sovklader','Pajmas/Sleepwear')
# df3['category']=df3['category'].str.replace('ullklader','Klader/Wool')    #odd    
# df3['category']=df3['category'].str.replace('underklader','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('uv-bad','Klader/Uvclothing') #odd
# df3['category']=df3['category'].str.replace('vaskor','Accessories/Bags') 
# df3['category']=df3['category'].str.replace('ytterklader','Klader/Outerwear') #includes all
# df3['category']=df3['category'].str.replace('overdelar','Tops')      
# df3['category']=df3['category'].str.replace('shoes','Footwear')
# df3['category']=df3['category'].str.replace('YTTERJACKOR','Jackets')                                           
# df3['category']=df3['category'].str.replace('SWEATSHIRTS','Jackets/Sweatshirts')
# df3['category']=df3['category'].str.replace('STICKAT','Knitwear')                        
# df3['category']=df3['category'].str.replace('TRÖJOR','Winter Jackets/Sweaters')
# df3['category']=df3['category'].str.replace('Lisas','Klader/Lisas')                                           
# df3['category']=df3['category'].str.replace('SKJORTOR','Shirts')                                   
# df3['category']=df3['category'].str.replace('JEANS','Bottoms/Jeans')                                           
# df3['category']=df3['category'].str.replace('BYXOR','Bottoms/Pants')
# df3['category']=df3['category'].str.replace('BERMUDASHORTS','Bottoms/Bermudashorts')                                           
# df3['category']=df3['category'].str.replace('SKOR','Footwear')
# df3['category']=df3['category'].str.replace('VÄSKOR OCH RYGGSÄCKAR','Accessories/Bags and Backpacks')                                           
# df3['category']=df3['category'].str.replace('UNDERKLÄDER OCH PYJAMASAR','Klader/Underwear and Pyjamas')
# df3['category']=df3['category'].str.replace('PYJAMAS OCH UNDERKLÄDER','Klader/Underwear and Pyjamas')                                             
# df3['category']=df3['category'].str.replace('Sockor','Footwear/Socks')
# df3['category']=df3['category'].str.replace('Kepsar och Mössor','Klader/Kepsar och Mössor')                                           
# df3['category']=df3['category'].str.replace('Accessoarer','Accessories')                                           
# df3['category']=df3['category'].str.replace('TOPPAR','Tops')
# df3['category']=df3['category'].str.replace('BYXOR OCH SHORTS','Klader/Pants and Shorts')                                           
# df3['category']=df3['category'].str.replace('KLÄNNINGAR','Dresses')
# df3['category']=df3['category'].str.replace('LEGGINGS OCH BYXOR','Bottoms/Leggings and Pants')                                           
# df3['category']=df3['category'].str.replace('KJOL','Skirts')
# df3['category']=df3['category'].str.replace('SHORTS','Bottoms/Shorts')                                                 
# df3['category']=df3['category'].str.replace('BADKLÄDER','Badklader')            
# df3['category']=df3['category'].str.replace('Sockor och strumpbyxor','Klader/Socks and Trousers')
# df3['category']=df3['category'].str.replace('ACCESSOARER','Accessories')                                           
# df3['category']=df3['category'].str.replace('Hats','Accessories/Hats')
# df3['category']=df3['category'].str.replace('KJOLAR OCH SHORTS','Klader/Skirts and Shorts')  
# df3['category']=df3['category'].str.replace('T-SHIRTAR OCH BODIES','Klader/Tshirts and Bodies')
# df3['category']=df3['category'].str.replace('Pyjamas och underkläder','Klader/Pyjamas and Underwear')                                                                     
# df3['category']=df3['category'].str.replace('HÄNGSELBYXOR','Bottoms/Hingepants')        
# df3['category']=df3['category'].str.replace('KLÄNNINGAR OCH SPARKBYXOR','Klader/Dresses and Sparkbyxor')
# df3['category']=df3['category'].str.replace('SKJORTOR OCH BODIES','Klader/Shirts and Bodies')                                                 
# df3['category']=df3['category'].str.replace('SHORTS OCH TROSOR','Klader/Shirts and Trousers')                                           
# df3['category']=df3['category'].str.replace('shoe','Footwear')
# df3['category']=df3['category'].str.replace('sport shoes','Footwear/Sportshoes') 
# df3['category']=df3['category'].str.replace('sandals','Footwear/Sandals')
# df3['category']=df3['category'].str.replace('rubber boots','Footwear/Rubberboots')                                           
# df3['category']=df3['category'].str.replace('boots','Footwear/Boots')
# df3['category']=df3['category'].str.replace('accessories','Accessories')                                               
# df3['category']=df3['category'].str.replace('Underkläder & Nattplagg\n(292)','Klader/Underwear and Nightwear')                                           
# df3['category']=df3['category'].str.replace('T-shirts & Linnen\n(111)','Klader/shirts and Linnen')
# # df3['category']=df3['category'].str.replace('Nyheter\n(418)','Klader/Newclothes')                                                 
# # df3['category']=df3['category'].str.replace('Badkläder\n(90)','Badklader')       
# # df3['category']=df3['category'].str.replace('Strumpor\n(138)','Footwear/Socks')
# # df3['category']=df3['category'].str.replace('Shorts\n(35)','Bottoms/Shorts')                                           
# # df3['category']=df3['category'].str.replace('Klänningar\n(61)','Dresses')
# # df3['category']=df3['category'].str.replace('3 för 2\n(159)','Klader/3 for 2')                                           
# # df3['category']=df3['category'].str.replace('PO.P Originals\n(196)','Klader/pop brand')
# # df3['category']=df3['category'].str.replace('Tröjor & Toppar\n(139)','Klader/Trousers and Tops')                                                                                    
# # df3['category']=df3['category'].str.replace('Accessoarer & Övrigt\n(216)','Accessories')  
# # df3['category']=df3['category'].str.replace('Leggings\n(52)','Bottoms/Leggings')
# # df3['category']=df3['category'].str.replace('Byxor & Jumpsuits\n(129)','Klader/Pants and Jumpsuits')                                                                         
# # df3['category']=df3['category'].str.replace('Bodies & Sparkdräkter\n(93)','Klader/Bodies and Sparkcostumes')                                           
# # df3['category']=df3['category'].str.replace('Ull & Underställ\n(170)','Klader/Wool')
# # df3['category']=df3['category'].str.replace('UV-kläder\n(46)','Klader/Uvclothing')      
# # df3['category']=df3['category'].str.replace('Outlet\n(77)','Klader/pop brand')                                           
# # df3['category']=df3['category'].str.replace('Solhattar\n(33)','Accessories/Sunhats')
# # df3['category']=df3['category'].str.replace('Kalsonger & Trosor\n(82)','Klader/Underwear and Trousers')                                               
# # df3['category']=df3['category'].str.replace('Ullkläder\n(158)','Klader/Wool')                                           
# # df3['category']=df3['category'].str.replace('Skor & Stövlar\n(34)','Klader/Shoes and Highshoes')                                           
# # df3['category']=df3['category'].str.replace('Kepsar\n(19)','Accessories/Caps')                                           
# # df3['category']=df3['category'].str.replace('Jeans\n(56)','Bottoms/Jeans')  
# # df3['category']=df3['category'].str.replace('Badbyxor\n(24)','Badklader/Pants')                                           
# # df3['category']=df3['category'].str.replace('Skjortor & Blusar\n(26)','Klader/Shirts and Blouses')  
# df3['category']=df3['category'].str.replace('byxor-shorts','Klader/Pants and Shorts')
# df3['category']=df3['category'].str.replace('badklader','Badklader')                                           
# df3['category']=df3['category'].str.replace('barnset','Klader/Set')                                           
# df3['category']=df3['category'].str.replace('barnskor','Footwear')                                           
# df3['category']=df3['category'].str.replace('jumpsuits','Jumpsuits')                                           
# df3['category']=df3['category'].str.replace('klanningar-kjolar','Klader/Dresses and Skirts')                                           
# df3['category']=df3['category'].str.replace('sov-mysplagg','Pajamas/Sleepwear') 
# df3['category']=df3['category'].str.replace('toppar-blusar','Klader/Top and Blouses')                                           
# df3['category']=df3['category'].str.replace('trojor-koftor','Klader/Sweaters and Cardigans')  
# df3['category']=df3['category'].str.replace('traningsklader','Klader/Sportswear')                                           
# df3['category']=df3['category'].str.replace('babybodies-overaller','Klader/Bodysuits and Overalls')                                           
# df3['category']=df3['category'].str.replace('babyklanningar-tunikor','Klader/Dresses and Tunics')                                             
# df3['category']=df3['category'].str.replace('ytterklader-till-baby','Klader/Outerwear')                                           
# df3['category']=df3['category'].str.replace('babybyxor-jeans-leggings','Klader/Jeans and Leggings')                                           
# df3['category']=df3['category'].str.replace('babyunderklader-bad','Klader/Underwear and Swimwear')                                           
# df3['category']=df3['category'].str.replace('babyaccessoarer','Accessories')                                           
# df3['category']=df3['category'].str.replace('babyskor','Footwear')                                           
# df3['category']=df3['category'].str.replace('ytterkläder','Klader/Outerwear')                                           
# df3['category']=df3['category'].str.replace('funktionsplagg','Klader/Functionalclothing')                                           
# df3['category']=df3['category'].str.replace('training','Klader/Sportswear')                                           
# df3['category']=df3['category'].str.replace('toppar','Tops')                                           
# df3['category']=df3['category'].str.replace('tshirts','shirts')                                           
# df3['category']=df3['category'].str.replace('skjortor','Skirts')                                           
# df3['category']=df3['category'].str.replace('klanning-kjol','Klader/Dresses and Skirts')                                           
# df3['category']=df3['category'].str.replace('stickat','Knitwear')                                           
# df3['category']=df3['category'].str.replace('hoodar','Jackets/Hoodies')                                           
# df3['category']=df3['category'].str.replace('trojor','Bottoms/Trousers')                                           
# df3['category']=df3['category'].str.replace('swimwear','Badklader/Swimwear')                                           
# df3['category']=df3['category'].str.replace('barn-klader-toppar','Tops')                                           
# df3['category']=df3['category'].str.replace('barn-klader-trojor-koftor','Klader/Trousers and Jackets')                                           
# df3['category']=df3['category'].str.replace('barn-klader-byxor-jeans','Klader/Pants and Jeans')                                           
# df3['category']=df3['category'].str.replace('barn-sport-klader','Klader/Sportswear')                                           
# df3['category']=df3['category'].str.replace('barn-sport-skor','Footwear')                                           
# df3['category']=df3['category'].str.replace('barn-klader-underklader','Bottoms/Underwear')                                           
# df3['category']=df3['category'].str.replace('barn-klader-strumpor','Footwear/Socks')                                           
# df3['category']=df3['category'].str.replace('barn-klader-badmode','Badklader')        #odd                                   
# df3['category']=df3['category'].str.replace('barn-klader-baby-presenter','Klader/Presents') 
# df3['category']=df3['category'].str.replace('barn-accessoarer','Accessories')                                           
# df3['category']=df3['category'].str.replace('barn-klader-klanningar','Dresses')                                           
# df3['category']=df3['category'].str.replace('barn-klader-kjolar','Skirts')                                           
# df3['category']=df3['category'].str.replace('Dresses','Dresses')                                           
# df3['category']=df3['category'].str.replace('tops','Tops')                                           
# df3['category']=df3['category'].str.replace('bottoms','Bottoms')  
# df3['category']=df3['category'].str.replace('winterwear','Winterwear')  #odd 
# df3['category']=df3['category'].str.replace('jackor','Jackets')  
# df3['category']=df3['category'].str.replace('nightwear','Pajmas/Nightwear')  
# df3['category']=df3['category'].str.replace('Panties & Bra','Klader/Panties and Bra')  
# df3['category']=df3['category'].str.replace('socks','Footwear/Socks')  
# df3['category']=df3['category'].str.replace('acessoriesshoes','Footwear')  
# df3['category']=df3['category'].str.replace('trojor and koftor','Klader/Sweater and Cardigans')  
# df3['category']=df3['category'].str.replace('sports klader','Klader/Sportswear')  
# df3['category']=df3['category'].str.replace('stora klader','Klader/Large Clothes')  
# df3['category']=df3['category'].str.replace('underpants','Bottoms/Underpants')  
# df3['category']=df3['category'].str.replace('overdelar/s/629','Tops')  
# df3['category']=df3['category'].str.replace('trojor-stickat/s/1291','Klader/Sweaters and Knitwear ')  
# df3['category']=df3['category'].str.replace('klanningar/s/631','Dresses')  
# df3['category']=df3['category'].str.replace('underdelar/s/630','Bottoms')
# df3['category']=df3['category'].str.replace('shorts/s/646','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('kladset/s/1560','Klader/Set')
# df3['category']=df3['category'].str.replace('kostymer/s/1597','Costumes')  
# df3['category']=df3['category'].str.replace('fleece/s/662','Tops/Fleece')  
# df3['category']=df3['category'].str.replace('jackor/s/658','Jackets')
# df3['category']=df3['category'].str.replace('regnklader/s/661','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('sovklader/s/635','Pajamas/Sleepwear')
# df3['category']=df3['category'].str.replace('underklader/s/632','Bottoms/Underwear')  
# df3['category']=df3['category'].str.replace('uv-badklader/s/634','Klader/Uvclothing')  
# df3['category']=df3['category'].str.replace('barnskor/s/620','Footwear')
# df3['category']=df3['category'].str.replace('accessoarer/s/637','Accessories')
# df3['category']=df3['category'].str.replace('kjolar/s/643','Skirts')
# df3['category']=df3['category'].str.replace('overaller/s/659','Overalls')  
# df3['category']=df3['category'].str.replace('babyprodukter/s/621','Klader/Babyproducts')  
# df3['category']=df3['category'].str.replace('ni-baby-dresses-skirts','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('ni-mini-swimwear','Badklader/Swimwear')
# df3['category']=df3['category'].str.replace('ni-kids-swimwear','Badklader/Swimwear')
# df3['category']=df3['category'].str.replace('ni-kids-sportswear','Klader/Sportswear')
# df3['category']=df3['category'].str.replace('ni-teen-new-in','Klader/Newclothes')
# df3['category']=df3['category'].str.replace('ni-teen-tops','Tops')
# df3['category']=df3['category'].str.replace('ni-teen-knitwear-sweats','Klader/Knitwear and Sweatshirts')
# df3['category']=df3['category'].str.replace('ni-teen-shirts','shirts')
# df3['category']=df3['category'].str.replace('ni-teen-jeans','Bottoms/Jeans')
# df3['category']=df3['category'].str.replace('ni-teen-pants','Bottoms/Pants')
# df3['category']=df3['category'].str.replace('ni-teen-shorts','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('ni-teen-dresses-skirts','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('ni-teen-outerwear','Klader/Outerwear')
# df3['category']=df3['category'].str.replace('ni-teen-accessories','Accessories')
# df3['category']=df3['category'].str.replace('ni-teen-organic-cotton','Klader/Cotton')
# df3['category']=df3['category'].str.replace('ni-baby-tops-long-sleeved','Tops/Longsleeve')
# df3['category']=df3['category'].str.replace('ni-baby-tops-short-sleeved','Tops/Shortsleeve')
# df3['category']=df3['category'].str.replace('ni-baby-tops-knitwear-sweats','Klader/Knitwear and Sweatshirts')
# df3['category']=df3['category'].str.replace('ni-baby-bottoms-trousers','Bottoms/Trousers')
# df3['category']=df3['category'].str.replace('ni-baby-bottoms-jeans','Bottoms/Jeans')
# df3['category']=df3['category'].str.replace('ni-baby-bottoms-rompers-playsuits','Bodysuits')
# df3['category']=df3['category'].str.replace('ni-baby-bottoms-leggins','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('ni-baby-bottoms-shorts-knickers','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('ni-baby-outerwear-jackets','Jackets')
# df3['category']=df3['category'].str.replace('ni-baby-outerwear-pramsuits-snowsuits','Klader/Snowsuits')
# df3['category']=df3['category'].str.replace('ni-baby-outerwear-accessories','Accessories/Outerwear')
# df3['category']=df3['category'].str.replace('ni-baby-basics-bodysuits','Bodysuits/Basics')
# df3['category']=df3['category'].str.replace('ni-baby-basics-sleepwear','Pajamas/Sleepwear')
# df3['category']=df3['category'].str.replace('ni-baby-basics-socks-tights','Klader/Socks and Tights')
# df3['category']=df3['category'].str.replace('ni-baby-accessories-dribbler-bibs','Accessories/Dribblerbibs')
# df3['category']=df3['category'].str.replace('ni-baby-beanies-gloves','Klader/Beanies and gloves')
# df3['category']=df3['category'].str.replace('ni-mini-tops-short-sleeved','Tops/Shortsleeve')
# df3['category']=df3['category'].str.replace('ni-mini-tops-long-sleeved','Tops/Longsleeve')
# df3['category']=df3['category'].str.replace('ni-mini-tops-cardigans','Knitwear/Cardigan')
# df3['category']=df3['category'].str.replace('ni-mini-tops-sweats','Jackets/Sweatshirts')
# df3['category']=df3['category'].str.replace('ni-mini-tops-knitwear','Knitwear')
# df3['category']=df3['category'].str.replace('ni-mini-tops-shirts','Tops/Shirts')
# df3['category']=df3['category'].str.replace('ni-mini-bottoms-jeans','Bottoms/Jeans')
# df3['category']=df3['category'].str.replace('ni-mini-bottoms-trousers','Bottoms/Trousers')
# df3['category']=df3['category'].str.replace('ni-mini-bottoms-leggins','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('ni-mini-bottoms-jumpsuits','Jumpsuits')
# df3['category']=df3['category'].str.replace('ni-mini-bottoms-shorts-knickers','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('ni-mini-dresses','Dresses')
# df3['category']=df3['category'].str.replace('ni-mini-skirts','Skirts')
# df3['category']=df3['category'].str.replace('ni-mini-outerwear-jackets','Winter Jackets')
# df3['category']=df3['category'].str.replace('ni-mini-outerwear-rainwear-thermo','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('ni-mini-outerwear-snowsuits','Klader/Snowsuits')
# df3['category']=df3['category'].str.replace('ni-mini-outerwear-accessories','Accessories/Outerwear')
# df3['category']=df3['category'].str.replace('ni-mini-basics-underwear','Bottoms/Underwearbasics')
# df3['category']=df3['category'].str.replace('ni-mini-basics-bodysuits','Bodysuits')
# df3['category']=df3['category'].str.replace('ni-mini-basics-sleepwear','Pajmas/Sleepwear')
# df3['category']=df3['category'].str.replace('ni-mini-basics-socks-tights','Klader/Socks and Tights')
# df3['category']=df3['category'].str.replace('ni-mini-accessories-shoes','Klader/Accessories and Shoes')
# df3['category']=df3['category'].str.replace('ni-mini-accessories-other','Accessories/Other')
# df3['category']=df3['category'].str.replace('ni-mini-accessories-beanies-gloves','Klader/Beanies and Gloves')
# df3['category']=df3['category'].str.replace('ni-kids-tops-short-sleeved','Tops/Shortsleeve')
# df3['category']=df3['category'].str.replace('ni-kids-tops-long-sleeved','Tops/Longsleeve')
# df3['category']=df3['category'].str.replace('ni-kids-tops-cardigans','Knitwear/Cardigan')
# df3['category']=df3['category'].str.replace('ni-kids-tops-sweats','Jackets/Sweatshirts')
# df3['category']=df3['category'].str.replace('ni-kids-tops-knitwear','Knitwear')
# df3['category']=df3['category'].str.replace('ni-kids-tops-shirts','Shirts')
# df3['category']=df3['category'].str.replace('ni-kids-bottoms-jeans','Bottoms/Jeans')
# df3['category']=df3['category'].str.replace('ni-kids-bottoms-trousers','Bottoms/Trousers')
# df3['category']=df3['category'].str.replace('ni-kids-bottoms-leggins','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('ni-kids-bottoms-jumpsuits','Jumpsuits')
# df3['category']=df3['category'].str.replace('ni-kids-bottoms-shorts-knickers','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('ni-kids-dresses','Dresses')
# df3['category']=df3['category'].str.replace('ni-kids-skirts','Skirts')
# df3['category']=df3['category'].str.replace('ni-kids-outerwear-jackets','Jackets/Outerwear')
# df3['category']=df3['category'].str.replace('ni-kids-outerwear-softshells','Jackets/Softshell')
# df3['category']=df3['category'].str.replace('ni-kids-outerwear-rainwear-thermo','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('ni-kids-outerwear-snowsuits','Klader/Snowsuits')
# df3['category']=df3['category'].str.replace('ni-kids-outerwear-accessories','Accessories/Outerwear')
# df3['category']=df3['category'].str.replace('ni-kids-basics-underwear','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('ni-kids-basics-sleepwear','Pajmas/Sleepwear')
# df3['category']=df3['category'].str.replace('ni-kids-basics-socks-tights','Klader/Socks and Tights')
# df3['category']=df3['category'].str.replace('ni-kids-accessories-other','Accessories/Other')
# df3['category']=df3['category'].str.replace('ni-kids-accessories-beanies-gloves','Klader/Beanies and Gloves')
# df3['category']=df3['category'].str.replace('ni-kids-sale-bottoms','Bottoms')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-mathilde-rosa','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-carla','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-mathilde-rosa','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-charlotte','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-lisa','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-baby-tops','Tops')                                          
# df3['category']=df3['category'].str.replace('ni-baby-bottoms','Bottoms')
# df3['category']=df3['category'].str.replace('ni-baby-outerwear','Klader/Outerwear')
# df3['category']=df3['category'].str.replace('ni-baby-basics','Klader/Basics')
# df3['category']=df3['category'].str.replace('ni-baby-accessories','Accessories')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-bastian','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-mustafa','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('ni-lmtd-ambassadors-kick','Klader/lmtd brand')
# df3['category']=df3['category'].str.replace('bodysuits','Bodysuits')
# df3['category']=df3['category'].str.replace('bedtextile','Klader/bedtextile')
# df3['category']=df3['category'].str.replace('fleece','Tops/Fleece')
# df3['category']=df3['category'].str.replace('scarves','Accessories/Scarves')
# df3['category']=df3['category'].str.replace('gloves','Accessories/Gloves')
# df3['category']=df3['category'].str.replace('gowns and jackets','Klader/Gowns and Jackets')
# df3['category']=df3['category'].str.replace('skirts','Skirts')
# df3['category']=df3['category'].str.replace('the','Klader/the')
# df3['category']=df3['category'].str.replace('dress','Dresses')
# df3['category']=df3['category'].str.replace('costumes','Costumes')
# df3['category']=df3['category'].str.replace('hats','Accessories/Hats')
# df3['category']=df3['category'].str.replace('overalls','Overalls')
# df3['category']=df3['category'].str.replace('sleepwear','Pajmas/Sleepwear')
# df3['category']=df3['category'].str.replace('sweaters and knitwear','Klader/Sweaters and Knitwear')
# df3['category']=df3['category'].str.replace('underwear','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('badklaeder','Badklader')
# df3['category']=df3['category'].str.replace('bodies','Bodysuits')
# df3['category']=df3['category'].str.replace('underklaeder-nattklaeder','Klader/underwear and nightwear')
# df3['category']=df3['category'].str.replace('strumpor-tights','Bottoms/Stocks and Tights')
# df3['category']=df3['category'].str.replace('activewear/overdelar','Tops/Activewear')
# df3['category']=df3['category'].str.replace('activewear/nederdelar','Skirts/Activewear')
# df3['category']=df3['category'].str.replace('activewear/skor','Footwear/Activewear')
# df3['category']=df3['category'].str.replace('activewear/accessoarer','Accessories/Activewear')
# df3['category']=df3['category'].str.replace('activewear/ytterklader','Klader/Activewear-Outerwear')
# df3['category']=df3['category'].str.replace('activewear/badklaeder','Pajmas/Activewear-Badklader')
# df3['category']=df3['category'].str.replace('Shorts','Bottoms/Shorts')
# df3['category']=df3['category'].str.replace('Badkläder &amp; UV','Klader/Badkläder and Uv')
# df3['category']=df3['category'].str.replace('Bodys &amp; set','Klader/Bodysuits and Sets')
# df3['category']=df3['category'].str.replace('Toppar &amp; t-shirts','Klader/Tops and Shirts')
# df3['category']=df3['category'].str.replace('Skjortor &amp; blusar','Klader/Shirts and Blouses')
# df3['category']=df3['category'].str.replace('Byxor','Bottoms/Pants')
# df3['category']=df3['category'].str.replace('Leggings','Bottoms/Leggings')
# df3['category']=df3['category'].str.replace('Jumpsuits &amp; onesies','Klader/Jumpsuits and Onesies')
# df3['category']=df3['category'].str.replace('Klänningar &amp; kjolar','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('Festkläder','Klader/Festivewear')
# df3['category']=df3['category'].str.replace('Tröjor &amp; koftor','Klader/Sweaters and Cardigans')
# df3['category']=df3['category'].str.replace('Ytterkläder','Klader/Outerwear')
# df3['category']=df3['category'].str.replace('Pyjamas','Pajmas')
# df3['category']=df3['category'].str.replace('Underkläder','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('Underställ','Bottoms/Chassis')
# df3['category']=df3['category'].str.replace('Skor','Footwear')
# df3['category']=df3['category'].str.replace('klanningar','Dresses')
# df3['category']=df3['category'].str.replace('kjolar','Skirts')
# df3['category']=df3['category'].str.replace('jackor-kapor','Klader/Jackets and Coats')
# df3['category']=df3['category'].str.replace('funktionklader','Klader/Funktionklader')
# df3['category']=df3['category'].str.replace('kladset','Klader/Kladset')
# df3['category']=df3['category'].str.replace('accesories','Accessories')
# df3['category']=df3['category'].str.replace('klanningnar-kjolar','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('funktionsklader','Klader/Dunktionklader')
# df3['category']=df3['category'].str.replace('trainingsklader','Klader/Sportswear')
# df3['category']=df3['category'].str.replace('byxor-leggings','Klader/Pants and Leggings')
# df3['category']=df3['category'].str.replace('toppar-trojar','Tops/Trousers')
# df3['category']=df3['category'].str.replace('STRUMPOR/SOCKOR','Footwear/Socks')
# df3['category']=df3['category'].str.replace('UNDERKLäDER','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('HALSDUKAR/SCARFS','Accessories/Scarves')
# df3['category']=df3['category'].str.replace('JACKOR/VäSTAR','Klader/Jackets and Bags')
# df3['category']=df3['category'].str.replace('REGNKLäDER','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('TäCKBYXOR/SKALBYXOR','Bottoms/Täckbyxor and Skalbyxor')
# df3['category']=df3['category'].str.replace('UNDERSTäLL','Bottoms/Chassis')
# df3['category']=df3['category'].str.replace('HUVTRöJOR','Jackets/Hoodies')
# df3['category']=df3['category'].str.replace('PIKE/RUGBYTRöJOR','Klader/Pike and Rugbytrojor')
# df3['category']=df3['category'].str.replace('SET/TRäNINGSOVERALLER','Klader/Overall')
# df3['category']=df3['category'].str.replace('T-SHIRT/LINNEN','Shirts/Linen')
# df3['category']=df3['category'].str.replace('TRöJOR/CARDIGANS','Klader/Trousers and Cardigans')
# df3['category']=df3['category'].str.replace('BADKLäDER/BADROCKAR','Badklader/Robe')
# df3['category']=df3['category'].str.replace('HANDDUKAR','Badklader/Towels')
# df3['category']=df3['category'].str.replace('KEPSAR','Accessories/Caps')
# df3['category']=df3['category'].str.replace('KLOCKOR','Accessories/Watches') #odd
# df3['category']=df3['category'].str.replace('MöSSOR','Accessories/Mössor')
# df3['category']=df3['category'].str.replace('SKäRP/BäLTEN','Accessories/Belts')
# df3['category']=df3['category'].str.replace('VANTAR','Accessories/Gloves')
# df3['category']=df3['category'].str.replace('VäSKOR/NECESSäRER','Accessories/Bags')
# df3['category']=df3['category'].str.replace('JUMPSUIT/BYXDRESS','Klader/Jumpsuits and Trousers')
# df3['category']=df3['category'].str.replace('KLäNNINGAR/KJOLAR','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('STRUMPBYXOR/LEGGINGS','Klader/Tights and Leggings')
# df3['category']=df3['category'].str.replace('TOPPAR/BLUSAR','Klader/Tops and Blouses')
# df3['category']=df3['category'].str.replace('tops and bodies','Klader/Tops and Bodies')
# df3['category']=df3['category'].str.replace('dresses and skirts','Klader/Dresses and Skirts')
# df3['category']=df3['category'].str.replace('pants','Bottoms/Pants')
# df3['category']=df3['category'].str.replace('stockings','Bottoms/Stockings')
# df3['category']=df3['category'].str.replace('outerwear','Klader/Outerwear')
# df3['category']=df3['category'].str.replace('shoes and acessories','Klader/Shoes and Accessories')
# df3['category']=df3['category'].str.replace('shirts and blouses','Klader/Shirts and Blouses')
# df3['category']=df3['category'].str.replace('sweaters','Winter Jackets/Sweaters')
# df3['category']=df3['category'].str.replace('BODIES & SPARKDRÄKTER','Klader/Bodysuits and Sparkdrakter')
# df3['category']=df3['category'].str.replace('BADBYXOR','Badkader/Swimwear')
# df3['category']=df3['category'].str.replace('BADDRÄKTER','Badklader/Swimsuits')
# df3['category']=df3['category'].str.replace('UV-KLÄDER','Klader/Uvclothing')
# df3['category']=df3['category'].str.replace('dresses','Dresses')
# df3['category']=df3['category'].str.replace('kardagins','Knitwear/Cardigans')
# df3['category']=df3['category'].str.replace('panties','Bottoms/Panties')
# df3['category']=df3['category'].str.replace('jackets','Jackets')
# df3['category']=df3['category'].str.replace('rainwear','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('badklader and uvklader','Klader/Badklader and Uvclothing')
# df3['category']=df3['category'].str.replace('bodies and sparkräkter','Klader/Bodysuits and Sparkrakter')
# df3['category']=df3['category'].str.replace('Dopkläder & högtidskläder','Klader/Baptimsal and Festivewear')
# df3['category']=df3['category'].str.replace('nederlander','Bottoms/Underwear')
# df3['category']=df3['category'].str.replace('regnklader','Klader/Rainwear')
# df3['category']=df3['category'].str.replace('ryggsackor and vaskor','Klader/Bags and Backpacks')
# df3['category']=df3['category'].str.replace('tecknat serier','Klader/Cartoon')
# df3['category']=df3['category'].str.replace('yttklader','Klader/Outerwear')
# df3['category']=df3['category'].str.replace('overdelear','Tops')
# df3['category']=df3['category'].str.replace('jul and luciaklader','Klader/Festivewear')
# df3['category']=df3['category'].str.replace('','Klader/')

# %%
# import csv
# list_old=[]
# list_new=[]
# la=str1.replace("df3['category']=df3['category'].str.replace",'')
# lb=la.replace("(","")
# lc=lb.replace(")","")
# reader = csv.reader(lc.split('\n'), delimiter=',')
# for row in reader:
#     if len(row)>1:
#         print(row[0]+',')

# %%
# import re
# new_list=re.findall(r"\(([^)]+)\)",str1)
# new_list

# %%
# stra=str1.find_all(",")
# strb=str1.find_all(")")
# new_str=[]
# for i in range(len(stra)):
#     new_str.append(str1[stra[i]+1:strb[i]].strip("'"))

# %%
# import re
# list1=re.findall(r"\(([^)]+)\)",str1)

# %%
# str2="'babyscarf','Accessories/Scarf'"
# for j in re.findall(r"'(.*?)'",str2):
#     print(j)

# %%
new_categorys=df3['category'].tolist()

# %%
# for j in list1:
#     print(j.split(","[1]))

# %%
# new_category=[]
# for i in new_categorys:
#     i.replace('babyscarf','Accessories/Scarf')
#     i.replace('babybody','Bodysuits')
#     i.replace('blus','Blouses')
#     i.replace('byxor','Bottoms')
#     i.replace('cardigan','Knitwear/Cardigan')
#     i.replace('halsduk','Accessories/Scarf')
#     i.replace('hatt','Accessories/Hats')
#     i.replace('hårband','Accessories/Hairband')
#     i.replace('jacka','Jackets')
#     i.replace('jumpsuit','Jumpsuits')
#     i.replace('kjol','Skirts')
#     i.replace('klänning','Dresses')
#     i.replace('leggings','Bottoms/Leggings')
#     i.replace('mössa','Accessories/Mössor')
#     i.replace('overall','Overalls')
#     i.replace('pannband','Accessories/hairband')                                           
#     i.replace('pufftrosa','Bottoms')
#     i.replace('pyjamas','Pajamas')
#     i.replace('skjorta','Tops')
#     i.replace('skor','Footwear')
#     i.replace('sovpåse','Accessories/Sleeping bags')
#     i.replace('stickad tröja','Shirts')
#     i.replace('strumpbyxor','Bottoms/Leggings')
#     i.replace('skjorta','Dresses')                                          
#     i.replace('shorts','Bottoms/Shorts')
#     i.replace('strumpor','Footwear/Socks')
#     i.replace('t-shirt','Shirts')
#     i.replace('tofflor','Footwear/Slippers')
#     i.replace('topp','Tops')                 
#     i.replace('tröja','Winter Jackets/Sweaters')
#     i.replace('vantar','Accessories/Gloves')
#     i.replace('väst','Coats/Vest')
#     i.replace('badbyxor','Bottoms/Swimming Trunks')
#     i.replace('baddräkt','Badklader/Swimwear') #odd
#     i.replace('dräkt','Costume Wear')
#     i.replace('fluga','Accessories/Bowtie')
#     i.replace('hängslen','Accessories/Braces')
#     i.replace('jeans','Bottoms/Jeans')
#     i.replace('keps','Accessories/Caps')                    
#     i.replace('väska','Accessories/Bags')
#     i.replace('badtröja','Badklader/Bathing Suit')
#     i.replace('bikinitrosa','Bottoms/Bikinitrosa')
#     i.replace('kappa','Coats')
#     i.replace('mockasiner','Shoes/Mockasiner')
#     i.replace('morgonrock','Badklader/Robe')
#     i.replace('trosa','Bottoms/trosa')
#     i.replace('tunika','Dresses/Tunics')
#     i.replace('diadem','Accessories/Tiara')
#     i.replace('handskar','Accessories/Gloves')
#     i.replace('kalsonger','Bottoms/Underwear')
#     i.replace('kostymväst','Coats/Vest')
#     i.replace('leksak','Toys') #not needed 
#     i.replace('långkalsonger','Bottoms/Long Underwear')
#     i.replace('maskeradaccessoar','Costume Wear/Accessories')
#     i.replace('skärp','Accessories/Belts')
#     i.replace('solglasögon','Accessories/Sunglasses')
#     i.replace('benvärmare','Bottoms/Legwarmers')
#     i.replace('bikinitopp','Tops/Bikini')
#     i.replace('bolero','Tops/Bolero')
#     i.replace('halsband','Accessories/Necklace')
#     i.replace('hårdekoration','Accessories/HairDecoration')
#     i.replace('hårsnodd','Accessories/Hairtie')
#     i.replace('hårspänne','Accessories/Hairpin')
#     i.replace('läppbalsam','Accessories/Lipbalm')
#     i.replace('nagellack','Accessories/Nailpolish')
#     i.replace('nattlinne','Pajamas/Nightgown') 
#     i.replace('pennfodral','Accessories/Pencilcase') #not needed
#     i.replace('poncho','Tops/Poncho')
#     i.replace('scarf','Accessories/Scarf')
#     i.replace('armband','Accessories/Armband')
#     i.replace('hörlurar','Accessories/Headphones')
#     i.replace('simglasögon','Accessories/Sunglasses')
#     i.replace('accessoarer','Accessories')
#     i.replace('barnklanningar-tunikor','Dresses/Tunics')
#     i.replace('bodys-bodysuits','Bodysuits')
#     i.replace('fleeceklader','Tops/Fleece')       #includes all tops jackets bottoms                                    
#     i.replace('hogtidsklader','Costume Wear/Holiday Clothing')
#     i.replace('jumpsuits-byxdressar','Jumpsuits')
#     i.replace('klad-gavoset','Klader/Giftset')                                           
#     i.replace('nederdelar','Skirts')
#     i.replace('sovklader','Pajmas/Sleepwear')
#     i.replace('ullklader','Klader/Wool')    #odd    
#     i.replace('underklader','Bottoms/Underwear')
#     i.replace('uv-bad','Klader/Uvclothing') #odd
#     i.replace('vaskor','Accessories/Bags') 
#     i.replace('ytterklader','Klader/Outerwear') #includes all
#     i.replace('overdelar','Tops')      
#     i.replace('shoes','Footwear')
#     i.replace('YTTERJACKOR','Jackets')                                           
#     i.replace('SWEATSHIRTS','Jackets/Sweatshirts')
#     i.replace('STICKAT','Knitwear')                        
#     i.replace('TRÖJOR','Winter Jackets/Sweaters')
#     i.replace('Lisas','Klader/Lisas')                                           
#     i.replace('SKJORTOR','Shirts')                                   
#     i.replace('JEANS','Bottoms/Jeans')                                           
#     i.replace('BYXOR','Bottoms/Pants')
#     i.replace('BERMUDASHORTS','Bottoms/Bermudashorts')                                           
#     i.replace('SKOR','Footwear')
#     i.replace('VÄSKOR OCH RYGGSÄCKAR','Accessories/Bags and Backpacks')                                           
#     i.replace('UNDERKLÄDER OCH PYJAMASAR','Klader/Underwear and Pyjamas')
#     i.replace('PYJAMAS OCH UNDERKLÄDER','Klader/Underwear and Pyjamas')                                             
#     i.replace('Sockor','Footwear/Socks')
#     i.replace('Kepsar och Mössor','Klader/Kepsar och Mössor')                                           
#     i.replace('Accessoarer','Accessories')                                           
#     i.replace('TOPPAR','Tops')
#     i.replace('BYXOR OCH SHORTS','Klader/Pants and Shorts')                                           
#     i.replace('KLÄNNINGAR','Dresses')
#     i.replace('LEGGINGS OCH BYXOR','Bottoms/Leggings and Pants')                                           
#     i.replace('KJOL','Skirts')
#     i.replace('SHORTS','Bottoms/Shorts')                                                 
#     i.replace('BADKLÄDER','Badklader')            
#     i.replace('Sockor och strumpbyxor','Klader/Socks and Trousers')
#     i.replace('ACCESSOARER','Accessories')                                           
#     i.replace('Hats','Accessories/Hats')
#     i.replace('KJOLAR OCH SHORTS','Klader/Skirts and Shorts')  
#     i.replace('T-SHIRTAR OCH BODIES','Klader/Tshirts and Bodies')
#     i.replace('Pyjamas och underkläder','Klader/Pyjamas and Underwear')                                                                     
#     i.replace('HÄNGSELBYXOR','Bottoms/Hingepants')        
#     i.replace('KLÄNNINGAR OCH SPARKBYXOR','Klader/Dresses and Sparkbyxor')
#     i.replace('SKJORTOR OCH BODIES','Klader/Shirts and Bodies')                                                 
#     i.replace('SHORTS OCH TROSOR','Klader/Shirts and Trousers')                                           
#     i.replace('shoe','Footwear')
#     i.replace('sport shoes','Footwear/Sportshoes') 
#     i.replace('sandals','Footwear/Sandals')
#     i.replace('rubber boots','Footwear/Rubberboots')                                           
#     i.replace('boots','Footwear/Boots')
#     i.replace('accessories','Accessories')                                               
#     i.replace('Underkläder & Nattplagg\n(292)','Klader/Underwear and Nightwear')                                           
#     i.replace('T-shirts & Linnen\n(111)','Klader/shirts and Linnen')
#     # i.replace('Nyheter\n(418)','Klader/Newclothes')                                                 
#     # i.replace('Badkläder\n(90)','Badklader')       
#     # i.replace('Strumpor\n(138)','Footwear/Socks')
#     # i.replace('Shorts\n(35)','Bottoms/Shorts')                                           
#     # i.replace('Klänningar\n(61)','Dresses')
#     # i.replace('3 för 2\n(159)','Klader/3 for 2')                                           
#     # i.replace('PO.P Originals\n(196)','Klader/pop brand')
#     # i.replace('Tröjor & Toppar\n(139)','Klader/Trousers and Tops')                                                                                    
#     # i.replace('Accessoarer & Övrigt\n(216)','Accessories')  
#     # i.replace('Leggings\n(52)','Bottoms/Leggings')
#     # i.replace('Byxor & Jumpsuits\n(129)','Klader/Pants and Jumpsuits')                                                                         
#     # i.replace('Bodies & Sparkdräkter\n(93)','Klader/Bodies and Sparkcostumes')                                           
#     # i.replace('Ull & Underställ\n(170)','Klader/Wool')
#     # i.replace('UV-kläder\n(46)','Klader/Uvclothing')      
#     # i.replace('Outlet\n(77)','Klader/pop brand')                                           
#     # i.replace('Solhattar\n(33)','Accessories/Sunhats')
#     # i.replace('Kalsonger & Trosor\n(82)','Klader/Underwear and Trousers')                                               
#     # i.replace('Ullkläder\n(158)','Klader/Wool')                                           
#     # i.replace('Skor & Stövlar\n(34)','Klader/Shoes and Highshoes')                                           
#     # i.replace('Kepsar\n(19)','Accessories/Caps')                                           
#     # i.replace('Jeans\n(56)','Bottoms/Jeans')  
#     # i.replace('Badbyxor\n(24)','Badklader/Pants')                                           
#     # i.replace('Skjortor & Blusar\n(26)','Klader/Shirts and Blouses')  
#     i.replace('byxor-shorts','Klader/Pants and Shorts')
#     i.replace('badklader','Badklader')                                           
#     i.replace('barnset','Klader/Set')                                           
#     i.replace('barnskor','Footwear')                                           
#     i.replace('jumpsuits','Jumpsuits')                                           
#     i.replace('klanningar-kjolar','Klader/Dresses and Skirts')                                           
#     i.replace('sov-mysplagg','Pajamas/Sleepwear') 
#     i.replace('toppar-blusar','Klader/Top and Blouses')                                           
#     i.replace('trojor-koftor','Klader/Sweaters and Cardigans')  
#     i.replace('traningsklader','Klader/Sportswear')                                           
#     i.replace('babybodies-overaller','Klader/Bodysuits and Overalls')                                           
#     i.replace('babyklanningar-tunikor','Klader/Dresses and Tunics')                                             
#     i.replace('ytterklader-till-baby','Klader/Outerwear')                                           
#     i.replace('babybyxor-jeans-leggings','Klader/Jeans and Leggings')                                           
#     i.replace('babyunderklader-bad','Klader/Underwear and Swimwear')                                           
#     i.replace('babyaccessoarer','Accessories')                                           
#     i.replace('babyskor','Footwear')                                           
#     i.replace('ytterkläder','Klader/Outerwear')                                           
#     i.replace('funktionsplagg','Klader/Functionalclothing')                                           
#     i.replace('training','Klader/Sportswear')                                           
#     i.replace('toppar','Tops')                                           
#     i.replace('tshirts','shirts')                                           
#     i.replace('skjortor','Skirts')                                           
#     i.replace('klanning-kjol','Klader/Dresses and Skirts')                                           
#     i.replace('stickat','Knitwear')                                           
#     i.replace('hoodar','Jackets/Hoodies')                                           
#     i.replace('trojor','Bottoms/Trousers')                                           
#     i.replace('swimwear','Badklader/Swimwear')                                           
#     i.replace('barn-klader-toppar','Tops')                                           
#     i.replace('barn-klader-trojor-koftor','Klader/Trousers and Jackets')                                           
#     i.replace('barn-klader-byxor-jeans','Klader/Pants and Jeans')                                           
#     i.replace('barn-sport-klader','Klader/Sportswear')                                           
#     i.replace('barn-sport-skor','Footwear')                                           
#     i.replace('barn-klader-underklader','Bottoms/Underwear')                                           
#     i.replace('barn-klader-strumpor','Footwear/Socks')                                           
#     i.replace('barn-klader-badmode','Badklader')        #odd                                   
#     i.replace('barn-klader-baby-presenter','Klader/Presents') 
#     i.replace('barn-accessoarer','Accessories')                                           
#     i.replace('barn-klader-klanningar','Dresses')                                           
#     i.replace('barn-klader-kjolar','Skirts')                                           
#     i.replace('Dresses','Dresses')                                           
#     i.replace('tops','Tops')                                           
#     i.replace('bottoms','Bottoms')  
#     i.replace('winterwear','Winterwear')  #odd 
#     i.replace('jackor','Jackets')  
#     i.replace('nightwear','Pajmas/Nightwear')  
#     i.replace('Panties & Bra','Klader/Panties and Bra')  
#     i.replace('socks','Footwear/Socks')  
#     i.replace('acessoriesshoes','Footwear')  
#     i.replace('trojor and koftor','Klader/Sweater and Cardigans')  
#     i.replace('sports klader','Klader/Sportswear')  
#     i.replace('stora klader','Klader/Large Clothes')  
#     i.replace('underpants','Bottoms/Underpants')  
#     i.replace('overdelar/s/629','Tops')  
#     i.replace('trojor-stickat/s/1291','Klader/Sweaters and Knitwear ')  
#     i.replace('klanningar/s/631','Dresses')  
#     i.replace('underdelar/s/630','Bottoms')
#     i.replace('shorts/s/646','Bottoms/Shorts')
#     i.replace('kladset/s/1560','Klader/Set')
#     i.replace('kostymer/s/1597','Costumes')  
#     i.replace('fleece/s/662','Tops/Fleece')  
#     i.replace('jackor/s/658','Jackets')
#     i.replace('regnklader/s/661','Klader/Rainwear')
#     i.replace('sovklader/s/635','Pajamas/Sleepwear')
#     i.replace('underklader/s/632','Bottoms/Underwear')  
#     i.replace('uv-badklader/s/634','Klader/Uvclothing')  
#     i.replace('barnskor/s/620','Footwear')
#     i.replace('accessoarer/s/637','Accessories')
#     i.replace('kjolar/s/643','Skirts')
#     i.replace('overaller/s/659','Overalls')  
#     i.replace('babyprodukter/s/621','Klader/Babyproducts')  
#     i.replace('ni-baby-dresses-skirts','Klader/Dresses and Skirts')
#     i.replace('ni-mini-swimwear','Badklader/Swimwear')
#     i.replace('ni-kids-swimwear','Badklader/Swimwear')
#     i.replace('ni-kids-sportswear','Klader/Sportswear')
#     i.replace('ni-teen-new-in','Klader/Newclothes')
#     i.replace('ni-teen-tops','Tops')
#     i.replace('ni-teen-knitwear-sweats','Klader/Knitwear and Sweatshirts')
#     i.replace('ni-teen-shirts','shirts')
#     i.replace('ni-teen-jeans','Bottoms/Jeans')
#     i.replace('ni-teen-pants','Bottoms/Pants')
#     i.replace('ni-teen-shorts','Bottoms/Shorts')
#     i.replace('ni-teen-dresses-skirts','Klader/Dresses and Skirts')
#     i.replace('ni-teen-outerwear','Klader/Outerwear')
#     i.replace('ni-teen-accessories','Accessories')
#     i.replace('ni-teen-organic-cotton','Klader/Cotton')
#     i.replace('ni-baby-tops-long-sleeved','Tops/Longsleeve')
#     i.replace('ni-baby-tops-short-sleeved','Tops/Shortsleeve')
#     i.replace('ni-baby-tops-knitwear-sweats','Klader/Knitwear and Sweatshirts')
#     i.replace('ni-baby-bottoms-trousers','Bottoms/Trousers')
#     i.replace('ni-baby-bottoms-jeans','Bottoms/Jeans')
#     i.replace('ni-baby-bottoms-rompers-playsuits','Bodysuits')
#     i.replace('ni-baby-bottoms-leggins','Bottoms/Leggings')
#     i.replace('ni-baby-bottoms-shorts-knickers','Bottoms/Shorts')
#     i.replace('ni-baby-outerwear-jackets','Jackets')
#     i.replace('ni-baby-outerwear-pramsuits-snowsuits','Klader/Snowsuits')
#     i.replace('ni-baby-outerwear-accessories','Accessories/Outerwear')
#     i.replace('ni-baby-basics-bodysuits','Bodysuits/Basics')
#     i.replace('ni-baby-basics-sleepwear','Pajamas/Sleepwear')
#     i.replace('ni-baby-basics-socks-tights','Klader/Socks and Tights')
#     i.replace('ni-baby-accessories-dribbler-bibs','Accessories/Dribblerbibs')
#     i.replace('ni-baby-beanies-gloves','Klader/Beanies and gloves')
#     i.replace('ni-mini-tops-short-sleeved','Tops/Shortsleeve')
#     i.replace('ni-mini-tops-long-sleeved','Tops/Longsleeve')
#     i.replace('ni-mini-tops-cardigans','Knitwear/Cardigan')
#     i.replace('ni-mini-tops-sweats','Jackets/Sweatshirts')
#     i.replace('ni-mini-tops-knitwear','Knitwear')
#     i.replace('ni-mini-tops-shirts','Tops/Shirts')
#     i.replace('ni-mini-bottoms-jeans','Bottoms/Jeans')
#     i.replace('ni-mini-bottoms-trousers','Bottoms/Trousers')
#     i.replace('ni-mini-bottoms-leggins','Bottoms/Leggings')
#     i.replace('ni-mini-bottoms-jumpsuits','Jumpsuits')
#     i.replace('ni-mini-bottoms-shorts-knickers','Bottoms/Shorts')
#     i.replace('ni-mini-dresses','Dresses')
#     i.replace('ni-mini-skirts','Skirts')
#     i.replace('ni-mini-outerwear-jackets','Winter Jackets')
#     i.replace('ni-mini-outerwear-rainwear-thermo','Klader/Rainwear')
#     i.replace('ni-mini-outerwear-snowsuits','Klader/Snowsuits')
#     i.replace('ni-mini-outerwear-accessories','Accessories/Outerwear')
#     i.replace('ni-mini-basics-underwear','Bottoms/Underwearbasics')
#     i.replace('ni-mini-basics-bodysuits','Bodysuits')
#     i.replace('ni-mini-basics-sleepwear','Pajmas/Sleepwear')
#     i.replace('ni-mini-basics-socks-tights','Klader/Socks and Tights')
#     i.replace('ni-mini-accessories-shoes','Klader/Accessories and Shoes')
#     i.replace('ni-mini-accessories-other','Accessories/Other')
#     i.replace('ni-mini-accessories-beanies-gloves','Klader/Beanies and Gloves')
#     i.replace('ni-kids-tops-short-sleeved','Tops/Shortsleeve')
#     i.replace('ni-kids-tops-long-sleeved','Tops/Longsleeve')
#     i.replace('ni-kids-tops-cardigans','Knitwear/Cardigan')
#     i.replace('ni-kids-tops-sweats','Jackets/Sweatshirts')
#     i.replace('ni-kids-tops-knitwear','Knitwear')
#     i.replace('ni-kids-tops-shirts','Shirts')
#     i.replace('ni-kids-bottoms-jeans','Bottoms/Jeans')
#     i.replace('ni-kids-bottoms-trousers','Bottoms/Trousers')
#     i.replace('ni-kids-bottoms-leggins','Bottoms/Leggings')
#     i.replace('ni-kids-bottoms-jumpsuits','Jumpsuits')
#     i.replace('ni-kids-bottoms-shorts-knickers','Bottoms/Shorts')
#     i.replace('ni-kids-dresses','Dresses')
#     i.replace('ni-kids-skirts','Skirts')
#     i.replace('ni-kids-outerwear-jackets','Jackets/Outerwear')
#     i.replace('ni-kids-outerwear-softshells','Jackets/Softshell')
#     i.replace('ni-kids-outerwear-rainwear-thermo','Klader/Rainwear')
#     i.replace('ni-kids-outerwear-snowsuits','Klader/Snowsuits')
#     i.replace('ni-kids-outerwear-accessories','Accessories/Outerwear')
#     i.replace('ni-kids-basics-underwear','Bottoms/Underwear')
#     i.replace('ni-kids-basics-sleepwear','Pajmas/Sleepwear')
#     i.replace('ni-kids-basics-socks-tights','Klader/Socks and Tights')
#     i.replace('ni-kids-accessories-other','Accessories/Other')
#     i.replace('ni-kids-accessories-beanies-gloves','Klader/Beanies and Gloves')
#     i.replace('ni-kids-sale-bottoms','Bottoms')
#     i.replace('ni-lmtd-ambassadors-mathilde-rosa','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-carla','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-mathilde-rosa','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-charlotte','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-lisa','Klader/lmtd brand')
#     i.replace('ni-baby-tops','Tops')                                          
#     i.replace('ni-baby-bottoms','Bottoms')
#     i.replace('ni-baby-outerwear','Klader/Outerwear')
#     i.replace('ni-baby-basics','Klader/Basics')
#     i.replace('ni-baby-accessories','Accessories')
#     i.replace('ni-lmtd-ambassadors-bastian','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-mustafa','Klader/lmtd brand')
#     i.replace('ni-lmtd-ambassadors-kick','Klader/lmtd brand')
#     i.replace('bodysuits','Bodysuits')
#     i.replace('bedtextile','Klader/bedtextile')
#     i.replace('fleece','Tops/Fleece')
#     i.replace('scarves','Accessories/Scarves')
#     i.replace('gloves','Accessories/Gloves')
#     i.replace('gowns and jackets','Klader/Gowns and Jackets')
#     i.replace('skirts','Skirts')
#     i.replace('the','Klader/the')
#     i.replace('dress','Dresses')
#     i.replace('costumes','Costumes')
#     i.replace('hats','Accessories/Hats')
#     i.replace('overalls','Overalls')
#     i.replace('sleepwear','Pajmas/Sleepwear')
#     i.replace('sweaters and knitwear','Klader/Sweaters and Knitwear')
#     i.replace('underwear','Bottoms/Underwear')
#     i.replace('badklaeder','Badklader')
#     i.replace('bodies','Bodysuits')
#     i.replace('underklaeder-nattklaeder','Klader/underwear and nightwear')
#     i.replace('strumpor-tights','Bottoms/Stocks and Tights')
#     i.replace('activewear/overdelar','Tops/Activewear')
#     i.replace('activewear/nederdelar','Skirts/Activewear')
#     i.replace('activewear/skor','Footwear/Activewear')
#     i.replace('activewear/accessoarer','Accessories/Activewear')
#     i.replace('activewear/ytterklader','Klader/Activewear-Outerwear')
#     i.replace('activewear/badklaeder','Pajmas/Activewear-Badklader')
#     i.replace('Shorts','Bottoms/Shorts')
#     i.replace('Badkläder &amp; UV','Klader/Badkläder and Uv')
#     i.replace('Bodys &amp; set','Klader/Bodysuits and Sets')
#     i.replace('Toppar &amp; t-shirts','Klader/Tops and Shirts')
#     i.replace('Skjortor &amp; blusar','Klader/Shirts and Blouses')
#     i.replace('Byxor','Bottoms/Pants')
#     i.replace('Leggings','Bottoms/Leggings')
#     i.replace('Jumpsuits &amp; onesies','Klader/Jumpsuits and Onesies')
#     i.replace('Klänningar &amp; kjolar','Klader/Dresses and Skirts')
#     i.replace('Festkläder','Klader/Festivewear')
#     i.replace('Tröjor &amp; koftor','Klader/Sweaters and Cardigans')
#     i.replace('Ytterkläder','Klader/Outerwear')
#     i.replace('Pyjamas','Pajmas')
#     i.replace('Underkläder','Bottoms/Underwear')
#     i.replace('Underställ','Bottoms/Chassis')
#     i.replace('Skor','Footwear')
#     i.replace('klanningar','Dresses')
#     i.replace('kjolar','Skirts')
#     i.replace('jackor-kapor','Klader/Jackets and Coats')
#     i.replace('funktionklader','Klader/Funktionklader')
#     i.replace('kladset','Klader/Kladset')
#     i.replace('accesories','Accessories')
#     i.replace('klanningnar-kjolar','Klader/Dresses and Skirts')
#     i.replace('funktionsklader','Klader/Dunktionklader')
#     i.replace('trainingsklader','Klader/Sportswear')
#     i.replace('byxor-leggings','Klader/Pants and Leggings')
#     i.replace('toppar-trojar','Tops/Trousers')
#     i.replace('STRUMPOR/SOCKOR','Footwear/Socks')
#     i.replace('UNDERKLäDER','Bottoms/Underwear')
#     i.replace('HALSDUKAR/SCARFS','Accessories/Scarves')
#     i.replace('JACKOR/VäSTAR','Klader/Jackets and Bags')
#     i.replace('REGNKLäDER','Klader/Rainwear')
#     i.replace('TäCKBYXOR/SKALBYXOR','Bottoms/Täckbyxor and Skalbyxor')
#     i.replace('UNDERSTäLL','Bottoms/Chassis')
#     i.replace('HUVTRöJOR','Jackets/Hoodies')
#     i.replace('PIKE/RUGBYTRöJOR','Klader/Pike and Rugbytrojor')
#     i.replace('SET/TRäNINGSOVERALLER','Klader/Overall')
#     i.replace('T-SHIRT/LINNEN','Shirts/Linen')
#     i.replace('TRöJOR/CARDIGANS','Klader/Trousers and Cardigans')
#     i.replace('BADKLäDER/BADROCKAR','Badklader/Robe')
#     i.replace('HANDDUKAR','Badklader/Towels')
#     i.replace('KEPSAR','Accessories/Caps')
#     i.replace('KLOCKOR','Accessories/Watches') #odd
#     i.replace('MöSSOR','Accessories/Mössor')
#     i.replace('SKäRP/BäLTEN','Accessories/Belts')
#     i.replace('VANTAR','Accessories/Gloves')
#     i.replace('VäSKOR/NECESSäRER','Accessories/Bags')
#     i.replace('JUMPSUIT/BYXDRESS','Klader/Jumpsuits and Trousers')
#     i.replace('KLäNNINGAR/KJOLAR','Klader/Dresses and Skirts')
#     i.replace('STRUMPBYXOR/LEGGINGS','Klader/Tights and Leggings')
#     i.replace('TOPPAR/BLUSAR','Klader/Tops and Blouses')
#     i.replace('tops and bodies','Klader/Tops and Bodies')
#     i.replace('dresses and skirts','Klader/Dresses and Skirts')
#     i.replace('pants','Bottoms/Pants')
#     i.replace('stockings','Bottoms/Stockings')
#     i.replace('outerwear','Klader/Outerwear')
#     i.replace('shoes and acessories','Klader/Shoes and Accessories')
#     i.replace('shirts and blouses','Klader/Shirts and Blouses')
#     i.replace('sweaters','Winter Jackets/Sweaters')
#     i.replace('BODIES & SPARKDRÄKTER','Klader/Bodysuits and Sparkdrakter')
#     i.replace('BADBYXOR','Badkader/Swimwear')
#     i.replace('BADDRÄKTER','Badklader/Swimsuits')
#     i.replace('UV-KLÄDER','Klader/Uvclothing')
#     i.replace('dresses','Dresses')
#     i.replace('kardagins','Knitwear/Cardigans')
#     i.replace('panties','Bottoms/Panties')
#     i.replace('jackets','Jackets')
#     i.replace('rainwear','Klader/Rainwear')
#     i.replace('badklader and uvklader','Klader/Badklader and Uvclothing')
#     i.replace('bodies and sparkräkter','Klader/Bodysuits and Sparkrakter')
#     i.replace('Dopkläder & högtidskläder','Klader/Baptimsal and Festivewear')
#     i.replace('nederlander','Bottoms/Underwear')
#     i.replace('regnklader','Klader/Rainwear')
#     i.replace('ryggsackor and vaskor','Klader/Bags and Backpacks')
#     i.replace('tecknat serier','Klader/Cartoon')
#     i.replace('yttklader','Klader/Outerwear')
#     i.replace('overdelear','Tops')
#     i.replace('jul and luciaklader','Klader/Festivewear')
# #     i.replace('','Klader/')

# %%
423-251
# Out:
# 172

# %%
df3['category'].unique().size
# Out:
# 423

# %%
# df3['category'].unique()

# %%
# df3['brand'].unique()
